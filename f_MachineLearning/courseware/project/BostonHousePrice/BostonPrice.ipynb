# %%
import numpy as np  # 矩阵操作
import pandas as pd # 数据表单处理

import statsmodels.api as sm

import matplotlib.pyplot as plt   #画图
import seaborn as sns
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\compat\pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
data = pd.read_csv("boston_housing.csv")

#通过观察前5行，了解数据每列（特征）的概况
data.head()
# Out:
#       CRIM  ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18   2.31     0  0.538  6.575  65.2  4.0900    1  296       15
# 1  0.02731   0   7.07     0  0.469  6.421  78.9  4.9671    2  242       17
# 2  0.02729   0   7.07     0  0.469  7.185  61.1  4.9671    2  242       17
# 3  0.03237   0   2.18     0  0.458  6.998  45.8  6.0622    3  222       18
# 4  0.06905   0   2.18     0  0.458  7.147  54.2  6.0622    3  222       18
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
# 从原始数据中分离输入特征x和输出y
y = data['MEDV'].values
X = data.drop('MEDV', axis = 1)
X_con=sm.add_constant(X)

# %%
est=sm.OLS(y,X_con)
est=est.fit()

# %%
est.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.740
# Model:                            OLS   Adj. R-squared:                  0.733
# Method:                 Least Squares   F-statistic:                     107.4
# Date:                Sun, 27 May 2018   Prob (F-statistic):          1.95e-134
# Time:                        18:34:51   Log-Likelihood:                -1499.9
# No. Observations:                 506   AIC:                             3028.
# Df Residuals:                     492   BIC:                             3087.
# Df Model:                          13
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         34.1736      4.964      6.884      0.000      24.420      43.927
# CRIM          -0.1081      0.033     -3.282      0.001      -0.173      -0.043
# ZN             0.0503      0.014      3.695      0.000       0.024       0.077
# INDUS          0.0263      0.062      0.425      0.671      -0.095       0.148
# CHAS           2.5942      0.865      2.999      0.003       0.895       4.294
# NOX          -17.1565      3.809     -4.505      0.000     -24.640      -9.673
# RM             3.8632      0.418      9.244      0.000       3.042       4.684
# AGE            0.0011      0.013      0.080      0.936      -0.025       0.027
# DIS           -1.4765      0.200     -7.390      0.000      -1.869      -1.084
# RAD            0.3139      0.067      4.702      0.000       0.183       0.445
# TAX           -0.0129      0.004     -3.420      0.001      -0.020      -0.005
# PTRATIO       -0.8851      0.124     -7.126      0.000      -1.129      -0.641
# B              0.0094      0.003      3.502      0.001       0.004       0.015
# LSTAT         -0.5235      0.051    -10.298      0.000      -0.623      -0.424
# ==============================================================================
# Omnibus:                      178.030   Durbin-Watson:                   1.071
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              783.045
# Skew:                           1.521   Prob(JB):                    9.20e-171
# Kurtosis:                       8.281   Cond. No.                     1.47e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.47e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
X=X.drop(['INDUS','AGE'], axis = 1)
X_con=sm.add_constant(X)

# %%
est=sm.OLS(y,X_con)
est=est.fit()

# %%
est.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.739
# Model:                            OLS   Adj. R-squared:                  0.734
# Method:                 Least Squares   F-statistic:                     127.4
# Date:                Sun, 27 May 2018   Prob (F-statistic):          1.68e-136
# Time:                        18:39:27   Log-Likelihood:                -1500.0
# No. Observations:                 506   AIC:                             3024.
# Df Residuals:                     494   BIC:                             3075.
# Df Model:                          11
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         34.0136      4.928      6.902      0.000      24.332      43.696
# CRIM          -0.1086      0.033     -3.305      0.001      -0.173      -0.044
# ZN             0.0495      0.013      3.696      0.000       0.023       0.076
# CHAS           2.6370      0.857      3.076      0.002       0.953       4.321
# NOX          -16.6423      3.520     -4.728      0.000     -23.558      -9.726
# RM             3.8538      0.406      9.484      0.000       3.055       4.652
# DIS           -1.4992      0.186     -8.060      0.000      -1.865      -1.134
# RAD            0.3054      0.064      4.794      0.000       0.180       0.431
# TAX           -0.0122      0.003     -3.605      0.000      -0.019      -0.006
# PTRATIO       -0.8766      0.122     -7.172      0.000      -1.117      -0.636
# B              0.0094      0.003      3.508      0.000       0.004       0.015
# LSTAT         -0.5205      0.048    -10.943      0.000      -0.614      -0.427
# ==============================================================================
# Omnibus:                      178.530   Durbin-Watson:                   1.070
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              789.136
# Skew:                           1.524   Prob(JB):                    4.38e-172
# Kurtosis:                       8.305   Cond. No.                     1.43e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.43e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
data_corr = data.corr().abs()

# %%
plt.subplots(figsize=(13, 9))
sns.heatmap(data_corr,annot=True)

# Mask unimportant features
sns.heatmap(data_corr, mask=data_corr < 1, cbar=False)

plt.savefig('house_coor.png' )
plt.show()
