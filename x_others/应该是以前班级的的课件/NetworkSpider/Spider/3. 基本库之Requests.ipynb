# %% [markdown]
# 我们了解了urllib的基本用法，但是其中确实有不方便的地方，比如处理网页验证和Cookies时，需要写Opener和Handler来处理。为了更加方便地实现这些操作，就有了更为强大的库requests，有了它，Cookies、登录验证、代理设置等操作都不是事儿。requests的官方文档有[中文版本](http://cn.python-requests.org/zh_CN/latest/)。

# %% [markdown]
# 要安装 Requests，只要在你的终端中运行这个简单命令即可：
# ```
# pip install requests
# ```

# %% [markdown]
# # 1. 基础用法

# %% [markdown]
# ## 1.1 发送请求

# %% [markdown]
# Requests 简便的 API 意味着所有 HTTP 请求类型都是显而易见的。下面我们看看requests的请求方式：

# %%
import requests

r = requests.get('http://httpbin.org/get')#get请求
# r = requests.post('http://httpbin.org/post')#post请求
print(r.text)
# r = requests.put('http://httpbin.org/put')
# r = requests.delete('http://httpbin.org/delete')
# r = requests.head('http://httpbin.org/get')
# r = requests.options('http://httpbin.org/get')

# %% [markdown]
# 这里分别用get()、post()、put()、delete()等方法实现了POST、PUT、DELETE等请求。是不是比urllib简单太多了？其实这只是冰山一角，更多的还在后面。

# %% [markdown]
# ## 1.2 GET请求

# %% [markdown]
# ### 1.2.1 传递参数

# %%
import requests
import json
params={
    'wd':'人工智能',
    'hello':'world'
}
url = 'http://httpbin.org/get'
r = requests.get(url=url,params=params)
print(r.url)
print(r.text)
# print(json.loads(r.text))
# print(type(json.loads(r.text)))
# print(r.json())
# print(type(r.json()))#响应体
# Out:
# http://httpbin.org/get?wd=%E4%BA%BA%E5%B7%A5%E6%99%BA%E8%83%BD&hello=world
# {
#   "args": {
#     "hello": "world",
#     "wd": "\u4eba\u5de5\u667a\u80fd"
#   },
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Connection": "close",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.19.1"
#   },
#   "origin": "183.15.178.105",
#   "url": "http://httpbin.org/get?wd=\u4eba\u5de5\u667a\u80fd&hello=world"
# }

# %% [markdown]
# 针对'http://httpbin.org/get?name=germey&age=22 '，一般情况下，这种信息数据会用字典来存储。那么，怎样来构造这个链接呢？这同样很简单，利用params这个参数就好了。

# %% [markdown]
# ## 1.3 响应信息

# %% [markdown]
# Requests 会自动解码来自服务器的内容。大多数 unicode 字符集都能被无缝地解码。请求发出后，Requests 会基于 HTTP 头部对响应的编码作出有根据的推测。以 GitHub 时间线为例：

# %%
import requests
r = requests.get('https://api.github.com/events')
print(type(r.text))#使用text可以获得，Requests 会使用其推测的文本编码
# print(r.text)
print(r.encoding)
# Out:
# <class 'str'>
# utf-8

# %% [markdown]
# ### 1.3.1 响应属性信息

# %% [markdown]
# 有很多属性和方法可以用来获取其他信息，比如状态码、响应头、Cookies等。示例如下

# %%
import requests

r = requests.get('https://www.douban.com')#get请求
print(type(r.status_code),r.status_code)#状态码
print(type(r.headers),r.headers)#响应头
print(type(r.cookies),r.cookies)#cookies
print(type(r.url),r.url)#url
# print(type(r.history),r.history)#history属性得到请求历史
requests.utils.dict_from_cookiejar(r.cookies)
# Out:
# <class 'int'> 200
# <class 'requests.structures.CaseInsensitiveDict'> {'Date': 'Thu, 13 Sep 2018 03:15:55 GMT', 'Content-Type': 'text/html; charset=utf-8', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'Keep-Alive': 'timeout=30', 'Vary': 'Accept-Encoding', 'X-Xss-Protection': '1; mode=block', 'X-Douban-Mobileapp': '0', 'Expires': 'Sun, 1 Jan 2006 01:00:00 GMT', 'Pragma': 'no-cache', 'Cache-Control': 'must-revalidate, no-cache, private', 'Set-Cookie': 'll="118282"; path=/; domain=.douban.com; expires=Fri, 13-Sep-2019 03:15:55 GMT, bid=Hf0wmwusFBk; Expires=Fri, 13-Sep-19 03:15:55 GMT; Domain=.douban.com; Path=/', 'X-DOUBAN-NEWBID': 'Hf0wmwusFBk', 'X-DAE-Node': 'brand13', 'X-DAE-App': 'sns', 'Server': 'dae', 'X-Frame-Options': 'SAMEORIGIN', 'Strict-Transport-Security': 'max-age=15552000;', 'Content-Encoding': 'gzip'}
# <class 'requests.cookies.RequestsCookieJar'> <RequestsCookieJar[<Cookie bid=Hf0wmwusFBk for .douban.com/>, <Cookie ll="118282" for .douban.com/>]>
# <class 'str'> https://www.douban.com/
# {'bid': 'Hf0wmwusFBk', 'll': '"118282"'}

# %% [markdown]
# 状态码常用来判断请求是否成功，而requests还提供了一个内置的状态码查询对象requests.codes，示例如下：

# %%
import requests
 
r = requests.get('http://www.douban.com/help.html')
if r.status_code == requests.codes.okay:
    print('存在')
else:
    print('Request Successfully')
# exit() if r.status_code == requests.codes.not_found else print('Request Successfully')

# %%
import requests
 
r = requests.get('http://www.douban.com')
print('sahdjkf') if not r.status_code == 404 else print('404 Not Found')
# Out:
# sahdjkf

# %% [markdown]
# 下面列出了返回码和相应的查询条件：

# %% [markdown]
# ```
# # 信息性状态码
# 100: ('continue',),
# 101: ('switching_protocols',),
# 102: ('processing',),
# 103: ('checkpoint',),
# 122: ('uri_too_long', 'request_uri_too_long'),
#
# # 成功状态码
# 200: ('ok', 'okay', 'all_ok', 'all_okay', 'all_good', '\\o/', '✓'),
# 201: ('created',),
# 202: ('accepted',),
# 203: ('non_authoritative_info', 'non_authoritative_information'),
# 204: ('no_content',),
# 205: ('reset_content', 'reset'),
# 206: ('partial_content', 'partial'),
# 207: ('multi_status', 'multiple_status', 'multi_stati', 'multiple_stati'),
# 208: ('already_reported',),
# 226: ('im_used',),
#
# # 重定向状态码
# 300: ('multiple_choices',),
# 301: ('moved_permanently', 'moved', '\\o-'),
# 302: ('found',),
# 303: ('see_other', 'other'),
# 304: ('not_modified',),
# 305: ('use_proxy',),
# 306: ('switch_proxy',),
# 307: ('temporary_redirect', 'temporary_moved', 'temporary'),
# 308: ('permanent_redirect',
#       'resume_incomplete', 'resume',), # These 2 to be removed in 3.0
#
# # 客户端错误状态码
# 400: ('bad_request', 'bad'),
# 401: ('unauthorized',),
# 402: ('payment_required', 'payment'),
# 403: ('forbidden',),
# 404: ('not_found', '-o-'),
# 405: ('method_not_allowed', 'not_allowed'),
# 406: ('not_acceptable',),
# 407: ('proxy_authentication_required', 'proxy_auth', 'proxy_authentication'),
# 408: ('request_timeout', 'timeout'),
# 409: ('conflict',),
# 410: ('gone',),
# 411: ('length_required',),
# 412: ('precondition_failed', 'precondition'),
# 413: ('request_entity_too_large',),
# 414: ('request_uri_too_large',),
# 415: ('unsupported_media_type', 'unsupported_media', 'media_type'),
# 416: ('requested_range_not_satisfiable', 'requested_range', 'range_not_satisfiable'),
# 417: ('expectation_failed',),
# 418: ('im_a_teapot', 'teapot', 'i_am_a_teapot'),
# 421: ('misdirected_request',),
# 422: ('unprocessable_entity', 'unprocessable'),
# 423: ('locked',),
# 424: ('failed_dependency', 'dependency'),
# 425: ('unordered_collection', 'unordered'),
# 426: ('upgrade_required', 'upgrade'),
# 428: ('precondition_required', 'precondition'),
# 429: ('too_many_requests', 'too_many'),
# 431: ('header_fields_too_large', 'fields_too_large'),
# 444: ('no_response', 'none'),
# 449: ('retry_with', 'retry'),
# 450: ('blocked_by_windows_parental_controls', 'parental_controls'),
# 451: ('unavailable_for_legal_reasons', 'legal_reasons'),
# 499: ('client_closed_request',),
#
# # 服务端错误状态码
# 500: ('internal_server_error', 'server_error', '/o\\', '✗'),
# 501: ('not_implemented',),
# 502: ('bad_gateway',),
# 503: ('service_unavailable', 'unavailable'),
# 504: ('gateway_timeout',),
# 505: ('http_version_not_supported', 'http_version'),
# 506: ('variant_also_negotiates',),
# 507: ('insufficient_storage',),
# 509: ('bandwidth_limit_exceeded', 'bandwidth'),
# 510: ('not_extended',),
# 511: ('network_authentication_required', 'network_auth', 'network_authentication')
# ```

# %% [markdown]
# ### 1.3.2 二进制响应内容

# %% [markdown]
# 图片、音频、视频这些文件本质上都是由二进制码组成的，由于有特定的保存格式和对应的解析方式，我们才可以看到这些形形色色的多媒体。所以，想要抓取它们，就要拿到它们的二进制码。

# %%
import requests

headers ={
    'User-Agent':'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/66.0.3359.139 Safari/537.36'
}

 
r = requests.get("http://mm.chinasareview.com/wp-content/uploads/2017a/08/02/01.jpg",headers=headers)
print(r.status_code)
print(r.text)
print(r.content)
with open('05.jpg','wb') as f:
    f.write(r.content)

# %% [markdown]
# 可以注意到，前者出现了乱码，后者结果前带有一个b，这代表是bytes类型的数据。由于图片是二进制数据，所以前者在打印时转化为str类型，也就是图片直接转化为字符串，这理所当然会出现乱码。
#
# 接着，我们将刚才提取到的图片保存下来：

# %%
import requests
 
r = requests.get("https://github.com/favicon.ico")
print(r.status_code)
print(r.content)
with open('favicon.ico', 'wb') as f:
    f.write(r.content)

# %% [markdown]
# ### 1.3.3  json响应内容

# %% [markdown]
# Requests 中也有一个内置的 JSON 解码器，助你处理 JSON 数据：

# %%
import requests
import json

r = requests.get('https://api.github.com/get')
print(type(r.text))
print(r.text)
print(type(r.json()))
print(r.json())
print(type(json.loads(r.text)))
print(json.loads(r.text))

# %% [markdown]
# 可以发现，调用json()方法，就可以将返回结果是JSON格式的字符串转化为字典。

# %% [markdown]
# ## 1.4 添加headers

# %% [markdown]
# 比如，在上面“知乎”的例子中，如果不传递headers，就不能正常请求：

# %% [markdown]
# 如果你想为请求添加 HTTP 头部，只要简单地传递一个 dict 给 headers 参数就可以了。

# %%
import requests
 
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/64.0.3282.186 Safari/537.36'
}
r = requests.get("https://www.zhihu.com/explore", headers=headers)
# print(r.text)
print(r.status_code)
# Out:
# 200

# %%
import requests

url='http://fm.shiyunjj.com/2019/1588/3ikq.jpg'

headers = {
    'Referer':'http://www.mmjpg.com/mm/1588/3',
    'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/67.0.3396.99 Safari/537.36'
}

r=requests.get(url=url,headers=headers,allow_redirects=False)
print(r.status_code)
# print(r.content)
with open('aab.jpg','wb') as f:
    f.write(r.content)
# Out:
# 200

# %% [markdown]
# ## 1.5 POST请求

# %%
help(requests.post)
# Out:
# Help on function post in module requests.api:
#
# post(url, data=None, json=None, **kwargs)
#     Sends a POST request.
#
#     :param url: URL for the new :class:`Request` object.
#     :param data: (optional) Dictionary (will be form-encoded), bytes, or file-like object to send in the body of the :class:`Request`.
#     :param json: (optional) json data to send in the body of the :class:`Request`.
#     :param \*\*kwargs: Optional arguments that ``request`` takes.
#     :return: :class:`Response <Response>` object
#     :rtype: requests.Response

# %% [markdown]
# 通常，你想要发送一些编码为表单形式的数据——非常像一个 HTML 表单。要实现这个，只需简单地传递一个字典给 data 参数。你的数据字典在发出请求时会自动编码为表单形式

# %%
import requests

headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/64.0.3282.186 Safari/537.36'
}
data ={
    'wd':'python',
    'aaaa':'bbbbb'
}
r=requests.post(url='http://httpbin.org/post',params={'wd':'python'},headers=headers,data=data)
print(r.text)
print(r.url)
# Out:
# {
#   "args": {
#     "wd": "python"
#   },
#   "data": "",
#   "files": {},
#   "form": {
#     "aaaa": "bbbbb",
#     "wd": "python"
#   },
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Connection": "close",
#     "Content-Length": "20",
#     "Content-Type": "application/x-www-form-urlencoded",
#     "Host": "httpbin.org",
#     "User-Agent": "Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/64.0.3282.186 Safari/537.36"
#   },
#   "json": null,
#   "origin": "183.15.178.105",
#   "url": "http://httpbin.org/post?wd=python"
# }
#
# http://httpbin.org/post?wd=python

# %% [markdown]
# # 2. 高级用法

# %% [markdown]
# 我们再来了解下requests的一些高级用法，如文件上传、cookie设置、代理设置等。

# %% [markdown]
# ## 2.1 上传文件

# %% [markdown]
# 我们知道requests可以模拟提交一些数据。假如有的网站需要上传文件，我们也可以用它来实现，这非常简单，示例如下：

# %%
import requests
 
files = {'file': open('cookies.txt', 'rb')}
r = requests.post("http://httpbin.org/post", files=files)
print(r.text)

# %% [markdown]
# # 2.2 模拟登陆

# %% [markdown]
# ### 2.2.1 用session模拟登陆

# %%
import requests
url = 'https://www.zhihu.com/signup?next=%2F'

headers= {
    "HOST": "www.zhihu.com",
    "Referer": "https://www.zhihu.com/",
    'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/67.0.3396.99 Safari/537.36'
}

data={'username':'13027937678','password':'Zyl17727478517'}
s = requests.session()
s.post(url,data=data,headers=headers)
r=s.get('https://www.zhihu.com',headers=headers,allow_redirects=False)
print(r.content.decode('utf-8'))
# Out:
# Redirecting to <a href="https://www.zhihu.com/signup?next=%2F">https://www.zhihu.com/signup?next=%2F</a>.

# %% [markdown]
# #### 2.2.2 把cookie放到headers里面进行模拟登陆

# %%
import requests
url = 'https://www.zhihu.com/'

headers={    
    'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/67.0.3396.99 Safari/537.36',
    'Cookie': '_xsrf=F5xzrmVujpiUFdKkH9kTG1pRlIWX9pR7; d_c0="ABDpbgWLeA6PTtOYbPKKw7h-eLdJ0cqiLFw=|1541387675"; _zap=f89f7cbb-8441-4bb3-b46e-b49d8947bcf8; q_c1=6e330507b25246f0ae679ff1cc7cca33|1544151065000|1541387672000; tst=r; __gads=ID=282b119eac68f728:T=1546934837:S=ALNI_Mb7CI5D8aRSfli913mSnofF0c-1AQ; __utma=155987696.1947136852.1546935188.1546935188.1546935188.1; __utmb=155987696.0.10.1546935188; __utmc=155987696; __utmz=155987696.1546935188.1.1.utmcsr=(direct)|utmccn=(direct)|utmcmd=(none); tgw_l7_route=8ffa4a0b7ecd9bdb5ad19b8c1037b063; capsion_ticket="2|1:0|10:1546936452|14:capsion_ticket|44:Nzc3ZGM0ZWJjOTU4NGJiZmI5ZWRhZDE4YjE4YjY5NzE=|380f1c35f84f4cacec30cb9ab6430fe44f7b90fc9cb6b52ea7a135373aa023e4"; z_c0="2|1:0|10:1546936461|4:z_c0|92:Mi4xbzJQZ0RRQUFBQUFBRU9sdUJZdDREaVlBQUFCZ0FsVk5qYTRoWFFCS05GZGJUQi1oeUo0QXpJbk9oQ3QwQlVGandB|ed811f32c42a4fe09462b57b3a85b759e912334ac36015c807ed30f95a408ec6"'
}
r=requests.get(url,headers=headers,allow_redirects=False)
print(r.content.decode('utf-8'))
# Out:
# <!doctype html>
# <html lang="zh" data-hairline="true" data-theme="light"><head><meta charSet="utf-8"/><title data-react-helmet="true">首页 - 知乎</title><meta name="viewport" content="width=device-width,initial-scale=1,maximum-scale=1"/><meta name="renderer" content="webkit"/><meta name="force-rendering" content="webkit"/><meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1"/><meta name="google-site-verification" content="FTeR0c8arOPKh8c5DYh_9uu98_zJbaWw53J-Sch9MTg"/><title>知乎 - 有问题上知乎</title><meta name="description" content="有问题，上知乎。知乎是中文互联网知名知识分享平台，以「知识连接一切」为愿景，致力于构建一个人人都可以便捷接入的知识分享网络，让人们便捷地与世界分享知识、经验和见解，发现更大的世界。"/><link rel="shortcut icon" type="image/x-icon" href="https://static.zhihu.com/static/favicon.ico"/><link rel="search" type="application/opensearchdescription+xml" href="https://static.zhihu.com/static/search.xml" title="知乎"/><link rel="dns-prefetch" href="//static.zhimg.com"/><link rel="dns-prefetch" href="//pic1.zhimg.com"/><link rel="dns-prefetch" href="//pic2.zhimg.com"/><link rel="dns-prefetch" href="//pic3.zhimg.com"/><link rel="dns-prefetch" href="//pic4.zhimg.com"/><link href="https://static.zhihu.com/heifetz/main.app.cdc9c6960907b5363122.css" rel="stylesheet"/><script defer="" crossOrigin="anonymous" src="https://unpkg.zhimg.com/@cfe/sentry-script@latest/dist/init.js" data-sentry-config="{&quot;dsn&quot;:&quot;https://65e244586890460588f00f2987137aa8@crash2.zhihu.com/193&quot;,&quot;sampleRate&quot;:0.1,&quot;release&quot;:&quot;800-269c4d6f&quot;,&quot;ignoreErrorNames&quot;:[&quot;NetworkError&quot;,&quot;SecurityError&quot;],&quot;ignoreErrors&quot;:[&quot;origin message&quot;,&quot;Network request failed&quot;,&quot;Loading chunk&quot;,&quot;这个系统不支持该功能。&quot;,&quot;Can&#x27;t find variable: webkit&quot;,&quot;Can&#x27;t find variable: $&quot;,&quot;内存不足&quot;,&quot;out of memory&quot;,&quot;DOM Exception 18&quot;,&quot;zfeedback sdk 初始化失败！&quot;,&quot;zfeedback sdk 加载失败！&quot;,&quot;The operation is insecure&quot;,&quot;[object Event]&quot;,&quot;[object FileError]&quot;,&quot;[object DOMError]&quot;,&quot;[object Object]&quot;,&quot;拒绝访问。&quot;,&quot;Maximum call stack size exceeded&quot;,&quot;UploadError&quot;,&quot;无法 fetch&quot;,&quot;draft-js&quot;,&quot;缺少 JavaScript 对象&quot;,&quot;componentWillEnter&quot;,&quot;componentWillLeave&quot;,&quot;componentWillAppear&quot;,&quot;getInlineStyleAt&quot;,&quot;getCharacterList&quot;],&quot;whitelistUrls&quot;:[&quot;static.zhihu.com&quot;]}"></script><script nonce="d1bcbd0d-84e8-4078-8976-6904cbb90e56">if (window.requestAnimationFrame) {    window.requestAnimationFrame(function() {      window.FIRST_ANIMATION_FRAME = Date.now();    });  }</script></head><body class="Entry-body"><div id="root"><div data-zop-usertoken="{}" data-reactroot=""><div class="LoadingBar"></div><div><header role="banner" class="Sticky AppHeader" data-za-module="TopNavBar"><div class="AppHeader-inner"><a href="//www.zhihu.com" aria-label="知乎"><svg viewBox="0 0 200 91" class="Icon ZhihuLogo ZhihuLogo--blue Icon--logo" style="height:30px;width:64px" width="64" height="30" aria-hidden="true"><title></title><g><path d="M53.29 80.035l7.32.002 2.41 8.24 13.128-8.24h15.477v-67.98H53.29v67.978zm7.79-60.598h22.756v53.22h-8.73l-8.718 5.473-1.587-5.46-3.72-.012v-53.22zM46.818 43.162h-16.35c.545-8.467.687-16.12.687-22.955h15.987s.615-7.05-2.68-6.97H16.807c1.09-4.1 2.46-8.332 4.1-12.708 0 0-7.523 0-10.085 6.74-1.06 2.78-4.128 13.48-9.592 24.41 1.84-.2 7.927-.37 11.512-6.94.66-1.84.785-2.08 1.605-4.54h9.02c0 3.28-.374 20.9-.526 22.95H6.51c-3.67 0-4.863 7.38-4.863 7.38H22.14C20.765 66.11 13.385 79.24 0 89.62c6.403 1.828 12.784-.29 15.937-3.094 0 0 7.182-6.53 11.12-21.64L43.92 85.18s2.473-8.402-.388-12.496c-2.37-2.788-8.768-10.33-11.496-13.064l-4.57 3.627c1.363-4.368 2.183-8.61 2.46-12.71H49.19s-.027-7.38-2.372-7.38zm128.752-.502c6.51-8.013 14.054-18.302 14.054-18.302s-5.827-4.625-8.556-1.27c-1.874 2.548-11.51 15.063-11.51 15.063l6.012 4.51zm-46.903-18.462c-2.814-2.577-8.096.667-8.096.667s12.35 17.2 12.85 17.9 ...

# %% [markdown]
# ### 2.2.3 将cookie值拿出来直接在requests中发送

# %%
import requests
url = 'https://www.zhihu.com/'

headers={    
    'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/67.0.3396.99 Safari/537.36'
}
cc={}
cookie= '_xsrf=F5xzrmVujpiUFdKkH9kTG1pRlIWX9pR7; d_c0="ABDpbgWLeA6PTtOYbPKKw7h-eLdJ0cqiLFw=|1541387675"; _zap=f89f7cbb-8441-4bb3-b46e-b49d8947bcf8; q_c1=6e330507b25246f0ae679ff1cc7cca33|1544151065000|1541387672000; tst=r; __gads=ID=282b119eac68f728:T=1546934837:S=ALNI_Mb7CI5D8aRSfli913mSnofF0c-1AQ; __utma=155987696.1947136852.1546935188.1546935188.1546935188.1; __utmb=155987696.0.10.1546935188; __utmc=155987696; __utmz=155987696.1546935188.1.1.utmcsr=(direct)|utmccn=(direct)|utmcmd=(none); tgw_l7_route=8ffa4a0b7ecd9bdb5ad19b8c1037b063; capsion_ticket="2|1:0|10:1546936452|14:capsion_ticket|44:Nzc3ZGM0ZWJjOTU4NGJiZmI5ZWRhZDE4YjE4YjY5NzE=|380f1c35f84f4cacec30cb9ab6430fe44f7b90fc9cb6b52ea7a135373aa023e4"; z_c0="2|1:0|10:1546936461|4:z_c0|92:Mi4xbzJQZ0RRQUFBQUFBRU9sdUJZdDREaVlBQUFCZ0FsVk5qYTRoWFFCS05GZGJUQi1oeUo0QXpJbk9oQ3QwQlVGandB|ed811f32c42a4fe09462b57b3a85b759e912334ac36015c807ed30f95a408ec6"'
for c in cookie.split(';'):
    cc[c.strip().split('=',maxsplit=1)[0]]=c.strip().split('=',maxsplit=1)[1]
r=requests.get(url,headers=headers,allow_redirects=False,cookies=cc)
print(r.content.decode('utf-8'))
# Out:
# <!doctype html>
# <html lang="zh" data-hairline="true" data-theme="light"><head><meta charSet="utf-8"/><title data-react-helmet="true">首页 - 知乎</title><meta name="viewport" content="width=device-width,initial-scale=1,maximum-scale=1"/><meta name="renderer" content="webkit"/><meta name="force-rendering" content="webkit"/><meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1"/><meta name="google-site-verification" content="FTeR0c8arOPKh8c5DYh_9uu98_zJbaWw53J-Sch9MTg"/><title>知乎 - 有问题上知乎</title><meta name="description" content="有问题，上知乎。知乎是中文互联网知名知识分享平台，以「知识连接一切」为愿景，致力于构建一个人人都可以便捷接入的知识分享网络，让人们便捷地与世界分享知识、经验和见解，发现更大的世界。"/><link rel="shortcut icon" type="image/x-icon" href="https://static.zhihu.com/static/favicon.ico"/><link rel="search" type="application/opensearchdescription+xml" href="https://static.zhihu.com/static/search.xml" title="知乎"/><link rel="dns-prefetch" href="//static.zhimg.com"/><link rel="dns-prefetch" href="//pic1.zhimg.com"/><link rel="dns-prefetch" href="//pic2.zhimg.com"/><link rel="dns-prefetch" href="//pic3.zhimg.com"/><link rel="dns-prefetch" href="//pic4.zhimg.com"/><link href="https://static.zhihu.com/heifetz/main.app.cdc9c6960907b5363122.css" rel="stylesheet"/><script defer="" crossOrigin="anonymous" src="https://unpkg.zhimg.com/@cfe/sentry-script@latest/dist/init.js" data-sentry-config="{&quot;dsn&quot;:&quot;https://65e244586890460588f00f2987137aa8@crash2.zhihu.com/193&quot;,&quot;sampleRate&quot;:0.1,&quot;release&quot;:&quot;800-269c4d6f&quot;,&quot;ignoreErrorNames&quot;:[&quot;NetworkError&quot;,&quot;SecurityError&quot;],&quot;ignoreErrors&quot;:[&quot;origin message&quot;,&quot;Network request failed&quot;,&quot;Loading chunk&quot;,&quot;这个系统不支持该功能。&quot;,&quot;Can&#x27;t find variable: webkit&quot;,&quot;Can&#x27;t find variable: $&quot;,&quot;内存不足&quot;,&quot;out of memory&quot;,&quot;DOM Exception 18&quot;,&quot;zfeedback sdk 初始化失败！&quot;,&quot;zfeedback sdk 加载失败！&quot;,&quot;The operation is insecure&quot;,&quot;[object Event]&quot;,&quot;[object FileError]&quot;,&quot;[object DOMError]&quot;,&quot;[object Object]&quot;,&quot;拒绝访问。&quot;,&quot;Maximum call stack size exceeded&quot;,&quot;UploadError&quot;,&quot;无法 fetch&quot;,&quot;draft-js&quot;,&quot;缺少 JavaScript 对象&quot;,&quot;componentWillEnter&quot;,&quot;componentWillLeave&quot;,&quot;componentWillAppear&quot;,&quot;getInlineStyleAt&quot;,&quot;getCharacterList&quot;],&quot;whitelistUrls&quot;:[&quot;static.zhihu.com&quot;]}"></script><script nonce="2de5ad0c-348e-4692-9a13-1fa7d89f9684">if (window.requestAnimationFrame) {    window.requestAnimationFrame(function() {      window.FIRST_ANIMATION_FRAME = Date.now();    });  }</script></head><body class="Entry-body"><div id="root"><div data-zop-usertoken="{}" data-reactroot=""><div class="LoadingBar"></div><div><header role="banner" class="Sticky AppHeader" data-za-module="TopNavBar"><div class="AppHeader-inner"><a href="//www.zhihu.com" aria-label="知乎"><svg viewBox="0 0 200 91" class="Icon ZhihuLogo ZhihuLogo--blue Icon--logo" style="height:30px;width:64px" width="64" height="30" aria-hidden="true"><title></title><g><path d="M53.29 80.035l7.32.002 2.41 8.24 13.128-8.24h15.477v-67.98H53.29v67.978zm7.79-60.598h22.756v53.22h-8.73l-8.718 5.473-1.587-5.46-3.72-.012v-53.22zM46.818 43.162h-16.35c.545-8.467.687-16.12.687-22.955h15.987s.615-7.05-2.68-6.97H16.807c1.09-4.1 2.46-8.332 4.1-12.708 0 0-7.523 0-10.085 6.74-1.06 2.78-4.128 13.48-9.592 24.41 1.84-.2 7.927-.37 11.512-6.94.66-1.84.785-2.08 1.605-4.54h9.02c0 3.28-.374 20.9-.526 22.95H6.51c-3.67 0-4.863 7.38-4.863 7.38H22.14C20.765 66.11 13.385 79.24 0 89.62c6.403 1.828 12.784-.29 15.937-3.094 0 0 7.182-6.53 11.12-21.64L43.92 85.18s2.473-8.402-.388-12.496c-2.37-2.788-8.768-10.33-11.496-13.064l-4.57 3.627c1.363-4.368 2.183-8.61 2.46-12.71H49.19s-.027-7.38-2.372-7.38zm128.752-.502c6.51-8.013 14.054-18.302 14.054-18.302s-5.827-4.625-8.556-1.27c-1.874 2.548-11.51 15.063-11.51 15.063l6.012 4.51zm-46.903-18.462c-2.814-2.577-8.096.667-8.096.667s12.35 17.2 12.85 17.9 ...

# %% [markdown]
# 前面我们使用urllib处理过Cookies，写法比较复杂，而有了requests，获取和设置Cookies只需一步即可完成。

# %% [markdown]
# 当然，你也可以通过cookies参数来设置，不过这样就需要构造RequestsCookieJar对象，而且需要分割一下cookies。这相对烦琐，不过效果是相同的

# %% [markdown]
# 测试后，发现同样可以正常登录天猫。

# %% [markdown]
# ## 2.3 会话维持

# %% [markdown]
# 在requests中，如果直接利用get()或post()等方法的确可以做到模拟网页的请求，但是这实际上是相当于不同的会话，也就是说相当于你用了两个浏览器打开了不同的页面。

# %%
import requests
 
requests.get('http://httpbin.org/cookies/set/number/123456789')
r = requests.get('http://httpbin.org/cookies')
print(r.text)
# Out:
# {
#   "cookies": {}
# }

# %% [markdown]
# 其实解决这个问题的主要方法就是维持同一个会话，也就是相当于打开一个新的浏览器选项卡而不是新开一个浏览器。但是我又不想每次设置cookies，那该怎么办呢？这时候就有了新的利器——Session对象。

# %%
import requests
 
s = requests.Session()#会话    
s.get('http://httpbin.org/cookies/set/number/123456789')
r = s.get('http://httpbin.org/cookies')
print(r.text)
# Out:
# {
#   "cookies": {
#     "number": "123456789"
#   }
# }

# %% [markdown]
# ## 2.4 SSL 证书验证

# %% [markdown]
# Requests 可以为 HTTPS 请求验证 SSL 证书，就像 web 浏览器一样。SSL 验证默认是开启的，如果证书验证失败，Requests 会抛出 SSLError:

# %% [markdown]
# 12306的证书没有被官方CA机构信任，会出现证书验证错误的结果。我们现在访问它，都可以看到一个证书问题的页面

# %%
import requests
 
r = requests.get('https://www.12306.cn')
print(r.text)
# Out:
# <!DOCTYPE html>
# <html>
#
# <head>
#     <meta charset="utf-8">
#     <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">
#     <title>ä¸­å½éè·¯12306</title>
#     <script>
#         window.startTime = new Date().getTime(); //"window.onloadå¤å¼å§æ¶é´:",window.startTime
#     </script>
#     <link rel="shortcut icon" href="images/favicon.ico" type="image/x-icon" />
#     <!-- <link href="./css/index.css" rel="stylesheet">
#     <link href="./css/global.css" rel="stylesheet">
#     <link href="./css/public.css" rel="stylesheet"> -->
#     <link href="./fonts/iconfont.css" rel="stylesheet">
#     <!-- æ¥æåå¸æ§ä»¶ -->
#     <!-- <link href="./css/common/calendarNew.css" rel="stylesheet">
#     <link href="./css/common/table.css" rel="stylesheet">
#     <link href="./css/common/station.css" rel="stylesheet">
#     <link rel="stylesheet" href="./css/main.css"> -->
#     <link rel="stylesheet" href="./css/index_y_v30001.css">
# </head>
# <style>
#     .typeahead li {
#         width: 265px;
#         padding-left: 10px;
#     }
#     a:hover {
#         color: #000;
#     }
# </style>
#
# <body>
#     <!-- é¡µé¢å è½½è¿åº¦ -->
#     <div id="page-loading" class="page-loading"></div>
#     <!-- å¤´é¨ -->
#     <div class="header">
#         <div class="header">
#     <div class="wrapper">
#         <!-- å¤´é¨åå®¹ -->
#         <div class="header-con">
#             <h1 class="logo">
#                 <a name="g_href" data-type="1" data-href="index.html" data-redirect="Y" href="javascript:;">ä¸­å½éè·¯12306</a>
#             </h1>
#             <div class="header-right">
#                 <!-- æç´¢æ¡ -->
#                 <div class="header-search">
#                     <div class="search-bd">
#                         <input type="password" value="" style="display:none">
#                         <input type="text" class="search-input" id="search-input" value="" placeholder="æç´¢è½¦ç¥¨/é¤é¥®/å¸¸æå®¢/ç¸å³è§ç« " auto-complete="new-password">
#                         <!-- æç´¢æç¤º -->
#                         <div class="search-down">
#                             <a href="javascript:;" class="close">å³é­</a>
#                             <ul class="search-down-list"></ul>
#                         </div>
#                         <!-- æç´¢åå² -->
#                         <div class="search-history">
#                             <a href="javascript:;" class="history-clear">æ¸é¤</a>
#                             <h3 class="search-history-tit">æç´¢åå²</h3>
#                             <ul class="search-history-list">
#
#                             </ul>
#                         </div>
#                     </div>
#                     <a class="search-btn" href="javascript:;">
#                         <i class="icon icon-search"></i>
#                     </a>
#                 </div>
#                 <!-- å³ä¾§èå -->
#                 <ul class="header-menu">
#                     <li class="menu-item menu-nav">
#                         <a name="g_href" data-type="2" data-href="view/index.html" data-redirect="Y" href="javascript:;" class="menu-nav-hd">æç12306
#                             <i class="caret"></i>
#                         </a>
#                         <ul class="menu-nav-bd">
#                             <li>
#                                 <a name="g_href" data-type="2" data-href="view/train_order.html" data-redirect="Y" href="javascript:;">ç«è½¦ç¥¨è®¢å</a>
#                             </li>
#                             <li>
#                                 <a name="g_href" data-type="2" data-href="view/personal_travel.html" data-redirect="Y"
#                                     href="javascript:;">æçè¡ç¨</a>
#                             </li>
#                             <li class="nav-line"></li>
#                             <li>
#                                 <a name="g_href" data-type="10" data-href="queryMyOrder.html" data-redirect="Y" href="javascript:;">æçé¤é¥®â¢ç¹äº§</a>
#                             </li>
#                             <li>
#                                 <a name="g_href" data-type="2" data-href="view/my_insurance.html" data-redirect="Y"
#                                     href="javascript:;">æçä¿é©</a>
#                             </li>
#                             <li>
#                                 <a name="g_href" data-type="3" data-href="welcome.html" data-redirect="Y" href="javascript:;">æçä¼å</a>
#                             </li>
#                             <li class="nav-line"></li>
#                             <li>
#                                 <a name="g_href" data-type="2" data-href="view/information.html" data-redirect="Y" href="javascript:;">æ¥çä¸ªäººä¿¡æ¯</a>
#                             </li>
#                             <li>
#                                 <a name="g_href" data-type="2" data-href="view/userSecurity.html" data-redirect="Y"
#                                     href="javascript:;">è´¦æ·å®å¨</a>
#                             </li>
#                             <li class="nav-line"></li>
#                             <li>
#                                 <a name="g_href" data-type="2" data-href="view/passengers.html" data-redirect="Y" href="javascript:;">å¸¸ç¨èç³»äºº</a>
#                             </li>
#                             <li>
#                                 <a name="g_href" data-type="2" data-href="view/address_init.html" data-redirect="Y"
#                                     href="javascript:;">è½¦ç¥¨å¿«éå°å</a>
#                             </li>
#                             <li class="nav-line"></li>
#                             <li>
#                                 <a name="g_href" data-type="2" data-href="view/icentre_serviceQuery.html" data-redirect="Y"
#                                     href="javascript:;">æ¸©é¦¨æå¡æ¥è¯¢</a>
#                             </li>
#                         </ul>
#                     </li>
#                     <li class="menu-item menu-line">|</li>
#                     <li id="J-header-login" class="menu-item menu-login">
#                         <a name="g_href" data-type="2" data-href="resources/login.html" data-redirect="Y" href="javascript:;">ç»å½</a><a
#                             name="g_href" data-type="2" data-href="regist/init" data-redirect="Y" href="javascript:;"
#                             class="ml">æ³¨å</a>
#                     </li>
#                     <li id="J-header-logout" style="display: none;" class="menu-item menu-nav menu-login">
#                         æ¨å¥½ï¼<a name="g_href" data-type="2" data-href="view/index.html" data-redirect="Y" href="javascript:;" class="txt-primary menu-nav-my-hd"></a>&nbsp;|&nbsp;<a class="logout" href="javascript:;">éåº</a>
#                     </li>
#                 </ul>
#             </div>
#         </div>
#     </div>
#     <!-- å¯¼èª -->
#     <div class="nav-box">
#         <ul class="nav">
#             <li id="J-index" class="nav-item nav-item-w1">
#                 <a name="g_href" data-type="1" data-href="index.html" data-redirect="Y" href="javascript:;" class="nav-hd">é¦é¡µ</a>
#             </li>
#             <li id="J-chepiao" class="nav-item nav-item-w1">
#                 <a href="javascript:void(0)" class="nav-hd">è½¦ç¥¨
#                     <i class="icon icon-down"></i>
#                 </a>
#                 <div class="nav-bd">
#                     <div class="nav-bd-item nav-col2">
#                         <h3 class="nav-tit">è´­ä¹°</h3>
#                         <ul class="nav-con">
#                             <li class="nav_dan">
#                                 <a name="g_href" data-type="2" data-href="leftTicket/init?linktypeid=dc" data-redirect="Y"
#                                     href="javascript:;">åç¨</a>
#                             </li>
#                             <li class="nav_wang">
#                                 <a name="g_href" data-type="2" data-href="leftTicket/init?linktypeid=wf" data-redirect="Y"
#                                     href="javascript:;">å¾è¿</a>
#                             </li>
#                             <li>
#                                 <a name="g_href" data-type="2" data-href="lcQuery/init" data-redirect="Y" href="javascript:;">æ¥ç»­æ¢ä¹</a>
#                             </li>
#                             <li></li>
#                         </ul>
#                     </div>
#                     <div class="nav-bd-item nav-col2">
#                         <h3 class="nav-tit">åæ´</h3>
#                         <ul class="nav-con">
#                             <li class="nav_ref">
#                                 <a name="g_href" data-type="2" data-href="view/train_order.html?type=2&typefilt=4"
#                                     data-redirect="Y" href="javascript:;">éç¥¨</a>
#                             </li>
#                             <li class="nav_res">
#                                 <a name="g_href" data-type="2" data-href="view/train_order.html?type=2&typefilt=2"
#                                     data-redirect="Y" href="javascript:;">æ¹ç­¾</a>
#                             </li>
#                             <li class="nav_chg">
#                                 <a name="g_href" data-type="2" data-href="view/train_order.html?type=2&typefilt=3"
#                                     data-redirect="Y" href="javascript:;">åæ´å°ç«</a>
#                             </li>
#                             <li></li>
#                         </ul>
#                     </div>
#                     <div class="nav-bd-item nav-col2">
#                         <h3 class="nav-tit border-none">æ´å¤</h3>
#                         <ul class="nav-con">
#                             <li>
#                                 <a name="g_href" data-type="1" data-href="view/ticket/zt_card.html" data-redirect="Y"
#                                     href="javascript:;">ä¸­éé¶éå¡</a>
#                             </li>
#                             <li class="border-none">
#                                 <a name="g_href" data-type="1" data-href="view/ticket/through_train.html" data-redirect="Y"
#                                     href="javascript:;">å¹¿ä¹ç´éè½¦</a>
#                             </li>
#                             <li>
#                                 <a name="g_href" data-type="1" data-href="view/ticket/railway.html" data-redirect="Y"
#                                     href="javascript:;">å¸éå¿«ééè·¯</a>
#                             </li>
#                             <li>
#                                 <a name="g_href" data-type="1" data-href="view/ticket/international_train.html"
#                                     data-redirect="Y" href="javascript:;">å½éåè½¦</a>
#                             </li>
#                         </ul>
#                     </div>
#                 </div>
#             </li>
#             <li id="J-tuangoufuwu" class="nav-item ">
#                 <a href="javascript:void(0) " class="nav-hd ">å¢è´­æå¡
#                     <i class="icon icon-down "></i>
#                 </a>
#                 <div class="nav-bd ">
#                     <div class="nav-bd-item nav-col6 ">
#                         <ul class="nav-con ">
#                             <li>
#                                 <a name="g_href" data-type="1" data-href="view/group/group_management.html?type=1" data-redirect="Y"
#                                     href="javascript:;">å¡å·¥äººå</a>
#                             </li>
#
#                             <li>
#                                 <a name="g_href" data-type="1" data-href="view/group/group_management.html?type=2"
#                                     data-redirect="Y" href="javascript:;">å­¦çå¢ä½</a>
#                             </li>
#                         </ul>
#                     </div>
#                 </div>
#             </li>
#             <li id="J-huiyuanfuwu" class="nav-item ">
#                 <a href="javascript:void(0) " class="nav-hd ">ä¼åæå¡
#                     <i class="icon icon-down "></i>
#                 </a>
#                 <div class="nav-bd ">
#                     <div class="nav-bd-item nav-col6">
#                         <ul class="nav-con ">
#                             <li>
#                                 <a name="g_href" data-type="3" data-href="index.html" data-redirect="Y" href="javascript:;">ä¼åç®¡ç</a>
#                             </li>
#                             <li>
#                                 <a name="g_href" data-type="3" data-href="index.html" data-redirect="Y" href="javascript:;">ç§¯åè´¦æ·</a>
#                             </li>
#                             <li>
#                                 <a name="g_href" data-type="3" data-href="index.html" data-redirect="Y" href="javascript:;">ç§¯ååæ¢</a>
#                             </li>
#                             <li>
#                                 <a name="g_href" data-type="3" data-href="index.html" data-redirect="Y" href="javascript:;">ä¼åä¸äº«</a>
#                             </li>
#                             <li class="border-none ">
#                                 <a name="g_href" data-type="3" data-href="welcome.html" data-redirect="Y" href="javascript:;">ä¼åä¸­å¿</a>
#                             </li>
#                         </ul>
#                     </div>
#                 </div>
#             </li>
#             <li id="J-zhanchefuwu" class="nav-item ">
#                 <a href="javascript:void(0) " class="nav-hd ">ç«è½¦æå¡
#                     <i class="icon icon-down "></i>
#                 </a>
#                 <div class="nav-bd ">
#                     <div class="nav-bd-item nav-col4 ">
#                         <ul class="nav-con ">
#                             <li>
#                                 <a name="g_href" data-type="2" data-href="view/icentre_qxyyInfo.html" data-redirect="Y" href="javascript:;">éç¹æå®¢é¢çº¦</a>
#                             </li>
#                             <li>
#                                 <a name="g_href" data-type="1" data-href="view/station/hand.html" data-redirect="Y"
#                                     href="javascript:;">ä¾¿æ°æè¿</a>
#                             </li>
#                             <li>
#                             	<a name="g_href" data-type="1" data-href="view/station/shared_Car.html" data-redirect="Y"
#                                     href="javascript:;">å±äº«æ±½è½¦</a>
#                             </li>
#                             <li>
#                                 <a name="g_href" data-type="4" data-href="czyd_2143/" data-redirect="Y" href="javascript:;">è½¦ç«å¼å¯¼</a>
#                             </li>
#                             <li>
#                                 <a name="g_href" data-type="2" data-href="view/icentre_lostInfo.html" data-redirect="Y" href="javascript:;">éå¤±ç©åæ¥æ¾</a>
#                             </li>
#                             <li>
#                                 <a name="g_href" data-type="1" data-href="view/station/train_intro.html" data-redirect="Y"
#                                     href="javascript:;">å¨è½¦ç»ä»ç»</a>
#                             </li>
#                             <li>
#                             	<a name="g_href" data-type="1" data-href="view/station/custom_PickUp.html"
#                                     data-redirect="Y" href="javascript:;">å®å¶æ¥é</a>
#                             </li>
#                             <li>
#                                 <a name="g_href" data-type="4" data-href="zcfc_2548/" data-redirect="Y" href="javascript:;">ç«è½¦é£é</a>
#                             </li>
#                         </ul>
#                     </div>
#                     <!-- <div class="nav-bd-item ">
#                         <ul class="nav-con ">
#                             <li>
#                                 <a name="g_href" data-type="4" data-href="czyd_2143/" data-redirect="Y" href="javascript:;">è½¦ç«å¼å¯¼</a>
#                             </li>
#                             <li>
#                                 <a name="g_href" data-type="4" data-href="zcfc_2548/" data-redirect="Y" href="javascript:;">ç«è½¦é£é</a>
#                             </li>
#                         </ul>
#                     </div> -->
#                 </div>
#             </li>
#             <li id="J-shanlvfuwu" class="nav-item ">
#                 <a href="javascript:void(0) " class="nav-hd ">åææå¡
#                     <i class="icon icon-down "></i>
#                 </a>
#                 <div class="nav-bd ">
#                     <div class="nav-bd-item nav-col6 ">
#                         <ul class="nav-con ">
#                             <li>
#                                 <a name="g_href" data-type="10" data-href="index.html" data-redirect="Y" href="javascript:;">é¤é¥®â¢ç¹äº§</a>
#                             </li>
#                             <li>
#                                 <a name="g_href" data-type="5" data-href="" data-redirect="Y" href="javascript:;">ææ¸¸</a>
#                             </li>
#                             <li>
#                                 <a name="g_href" data-type="2" data-href="view/my_insurance.html" data-redirect="Y" href="javascript:;">ä¿é©</a>
#                             </li>
#                         </ul>
#                     </div>
#                 </div>
#             </li>
#             <li id="J-chuxingzhinan" class="nav-item ">
#                 <a href="javascript:void(0) " class="nav-hd ">åºè¡æå
#                     <i class="icon icon-down "></i>
#                 </a>
#                 <div class="nav-bd ">
#                     <div class="nav-bd-item nav-col2 ">
#                         <h3 class="nav-tit ">å¸¸è§é®é¢</h3>
#                         <ul class="nav-con ">
#                             <li>
#                                 <a name="g_href" data-type="2" data-href="gonggao/ticketType.html" data-redirect="Y"
#                                     href="javascript:;">è½¦ç¥¨</a>
#                             </li>
#                             <li>
#                                 <a name="g_href" data-type="2" data-href="gonggao/ticketWindow.html" data-redirect="Y"
#                                     href="javascript:;">è´­ç¥¨</a>
#                             </li>
#                             <li>
#                                 <a name="g_href" data-type="2" data-href="gonggao/windowEndorse.html" data-redirect="Y"
#                                     href="javascript:;">æ¹ç­¾ãåæ´å°ç«</a>
#                             </li>
#                             <li>
#                                 <a name="g_href" data-type="2" data-href="gonggao/windowRefund.html" data-redirect="Y"
#                                     href="javascript:;">éç¥¨</a>
#                             </li>
#                             <li>
#                                 <a name="g_href" data-type="2" data-href="gonggao/help.html" data-redirect="Y" href="javascript:;"
#                                     class="txt-lighter">æ´å¤>></a>
#                             </li>
#                             <li></li>
#                         </ul>
#                     </div>
#                     <div class="nav-bd-item nav-col2 ">
#                         <h3 class="nav-tit ">æå®¢é¡»ç¥</h3>
#                         <ul class="nav-con ">
#                             <li>
#                                 <a name="g_href" data-type="2" data-href="gonggao/usersNeedToKnow.html?linktypeid=txt"
#                                     data-redirect="Y" href="javascript:;">éè·¯çµå­å®¢ç¥¨</a>
#                             </li>
#                             <li>
#                                 <a name="g_href" data-type="2" data-href="gonggao/saleTicketMeans.html?linktypeid=means5"
#                                     data-redirect="Y" href="javascript:;">èº«ä»½æ ¸éª</a>
#                             </li>
#                             <li>
#                                 <a name="g_href" data-type="2" data-href="gonggao/help.html" data-redirect="Y" href="javascript:;"
#                                     class="txt-lighter">æ´å¤>></a>
#                             </li>
#                             <li></li>
#                         </ul>
#                     </div>
#                     <div class="nav-bd-item nav-col2 ">
#                         <h3 class="nav-tit border-none ">ç¸å³ç« ç¨</h3>
#                         <ul class="nav-con ">
#                             <li>
#                                 <a name="g_href" data-type="2" data-href="gonggao/saleTicketMeans.html?linktypeid=means1"
#                                     data-redirect="Y" href="javascript:;">éè·¯äºèç½å®ç¥¨æè¡åæ³</a>
#                             </li>
#                             <li class="border-none">
#                                 <a name="g_href" data-type="2" data-href="gonggao/saleTicketMeans.html?linktypeid=means2"
#                                     data-redirect="Y" href="javascript:;">éè·¯æå®¢è¿è¾è§ç¨</a>
#                             </li>
#                             <li style="text-overflow:ellipsis;white-space:nowrap;">
#                                 <a name="g_href" data-type="2" data-href="gonggao/saleTicketMeans.html?linktypeid=means6"
#                                     data-redirect="Y" href="javascript:;">éè·¯è¿ç«ä¹è½¦ç¦æ­¢åéå¶æºå¸¦åå¬å</a>
#                             </li>
#                             <li class="border-none" style="text-overflow:ellipsis;white-space:nowrap;">
#                                 <a name="g_href" data-type="2" data-href="gonggao/saleTicketMeans.html?linktypeid=means7"
#                                     data-redirect="Y" href="javascript:;">å¹¿æ·±æ¸¯é«ééè·¯è·¨å¢æå®¢è¿è¾ç»ç»è§å</a>
#                             </li>
#                             <li>
#                                 <a name="g_href" data-type="2" data-href="gonggao/help.html" data-redirect="Y" href="javascript:;"
#                                     class="txt-lighter">æ´å¤>></a>
#                             </li>
#                             <li></li>
#                         </ul>
#                     </div>
#                 </div>
#             </li>
#             <li id="J-xinxichaxun" class="nav-item last ">
#                 <a href="javascript:void(0) " class="nav-hd ">ä¿¡æ¯æ¥è¯¢
#                     <i class="icon icon-down "></i>
#                 </a>
#                 <div class="nav-bd ">
#                     <div class="nav-bd-item nav-col5 ">
#                         <h3 class="nav-tit border-none ">å¸¸ç¨æ¥è¯¢</h3>
#                         <ul class="nav-con ">
#                             <li>
#                                 <a name="g_href" data-type="2" data-href="zwdch/init" data-redirect="Y" href="javascript:;">æ­£æç¹</a>
#                             </li>
#                             <li>
#                                 <a name="g_href" data-type="2" data-href="queryTrainInfo/init" data-redirect="Y" href="javascript:;">æ¶å»è¡¨</a>
#                             </li>
#                             <li>
#                                 <a name="g_href" data-type="2" data-href="leftTicketPrice/initPublicPrice"
#                                     data-redirect="Y" href="javascript:;">å¬å¸ç¥¨ä»·</a>
#                             </li>
#                             <li>
#                                 <a name="g_href" data-type="1" data-href="view/infos/ticket_check.html" data-redirect="Y"
#                                     href="javascript:;">æ£ç¥¨å£</a>
#                             </li>
#                             <li>
#                                 <a name="g_href" data-type="1" data-href="view/infos/sale_time.html" data-redirect="Y"
#                                     href="javascript:;">èµ·å®æ¶é´</a>
#                             </li>
#                             <li>
#                                 <a name="g_href" data-href="https://forecast.lytq.com/pc.html" data-redirect="N"
#                                     data-target="_blank" href="javascript:;">å¤©æ°</a>
#                             </li>
#                             <li>
#                                 <a name="g_href" data-type="1" data-href="view/infos/jiaotong.html" data-redirect="Y"
#                                     href="javascript:;">äº¤éæ¥è¯¢</a>
#                             </li>
#                             <li>
#                                 <a name="g_href" data-type="2" data-href="queryAgencySellTicket/init" data-redirect="Y"
#                                     href="javascript:;">ä»£å®ç¹</a>
#                             </li>
#                             <li>
#                                 <a name="g_href" data-type="1" data-href="view/infos/service_number.html" data-redirect="Y"
#                                     href="javascript:;">å®¢æçµè¯</a>
#                             </li>
#                             <li></li>
#                         </ul>
#                     </div>
#                     <div class="nav-bd-item ">
#                         <ul class="nav-con nav-con-pt ">
#                             <li class="border-none">
#                                 <a id="gLink" href="javascript:void(0)">ææ°åå¸</a>
#                             </li>
#                             <li class="border-none">
#                                 <a name="g_href" data-type="6" data-href="queryDishonest/init" data-redirect="Y" href="javascript:;">ä¿¡ç¨ä¿¡æ¯</a>
#                             </li>
#                         </ul>
#                     </div>
#                 </div>
#             </li>
#         </ul>
#     </div>
# </div>
#
#     </div>
#     <!-- æç´¢è½®æ­å¾ -->
#     <div class="section-first">
#         <!-- è½®æ­å¾ -->
#         <div class="fullSlide">
#             <div class="bd">
#                 <ul class="sowingMap">
#                 </ul>
#             </div>
#             <div class="hd">
#                 <ul></ul>
#             </div>
#         </div>
#         <!-- æ¥è¯¢æ¡ -->
#         <div class="search-index">
#             <!-- å·¦ä¾§èå -->
#             <ul class="search-side">
#                 <li class="active">
#                     <a href="javascript:void(0)">
#                         <i class="icon icon-huochepiao"></i>è½¦ç¥¨</a>
#                 </li>
#                 <li>
#                     <a href="javascript:void(0)">
#                         <i class="icon icon-cycx"></i>å¸¸ç¨æ¥è¯¢</a>
#                 </li>
#                 <li>
#                     <a href="javascript:void(0)">
#                         <i class="icon icon-dingcan"></i>è®¢é¤</a>
#                 </li>
#             </ul>
#             <!-- å³ä¾§åå®¹ -->
#             <div class="search-main">
#                 <!-- è½¦ç¥¨æ¥è¯¢ -->
#                 <div class="search-main-item" style="display: block">
#                     <div class="search-main-tab">
#                         <div class="search-tab-hd">
#                             <ul>
#                                 <li class="active">
#                                     <a href="javascript:void(0)">
#                                         <i class="icon icon-dancheng"></i>åç¨</a>
#                                 </li>
#                                 <li>
#                                     <a href="javascript:void(0)">
#                                         <i class="icon icon-wangfan"></i>å¾è¿</a>
#                                 </li>
#                                 <li>
#                                     <a href="javascript:void(0)">
#                                         <i class="icon icon-huancheng"></i>æ¥ç»­æ¢ä¹</a>
#                                 </li>
#                                 <li>
#                                     <a href="javascript:void(0)">
#                                         <i class="icon icon-chepiao"></i>éæ¹ç­¾</a>
#                                 </li>
#                             </ul>
#                         </div>
#                         <div class="search-tab-bd">
#                             <!-- åç¨ -->
#                             <div class="search-tab-item" style="display: block;">
#                                 <div class="search-form">
#                                     <div class="form-item-group">
#                                         <div class="form-item">
#                                             <label for="" class="form-label">åºåå°</label>
#                                             <div class="form-bd">
#                                                 <div class="input-box input-city">
#                                                     <input id="fromStation" type="hidden" value="" name="from_station" />
#                                                     <input type="text" class="input " value="" id="fromStationText">
#                                                     <i class="icon icon-place" data-click='fromStationText'></i>
#                                                 </div>
#                                             </div>
#                                         </div>
#                                         <div class="form-item">
#                                             <label for="" class="form-label">å°è¾¾å°</label>
#                                             <div class="form-bd">
#                                                 <div class="input-box input-city">
#                                                     <input id="toStation" type="hidden" value="" name="to_station" />
#                                                     <input type="text" class="input" value="" id="toStationText">
#                                                     <i class="icon icon-place" data-click='toStationText'></i>
#                                                 </div>
#                                             </div>
#                                         </div>
#                                         <div class="city-change">
#                                             <i class="icon icon-qiehuan" title="åæ¢" id="danChange"></i>
#                                         </div>
#                                     </div>
#                                     <div class="form-item">
#                                         <label for="" class="form-label">åºåæ¥æ</label>
#                                         <div class="form-bd">
#                                             <div class="input-box input-data">
#                                                 <input type="text" class="input" value="2018-07-21" id="train_date"
#                                                     readonly>
#                                                 <i class="icon icon-date" data-click='train_date'></i>
#                                             </div>
#                                         </div>
#                                     </div>
#                                     <div class="form-item form-item-check">
#                                         <div class="form-bd">
#                                             <ul class="check-list check-list-right">
#                                                 <li id="isStudentDan">å­¦ç
#                                                     <i></i>
#                                                 </li>
#                                                 <li id="isHighDan">é«é/å¨è½¦
#                                                     <i></i>
#                                                 </li>
#                                             </ul>
#                                         </div>
#                                     </div>
#                                     <div class="form-item form-item-btn">
#                                         <a href="javascript:void(0)" class="btn btn-primary form-block" id="search_one">æ¥&nbsp;&nbsp;&nbsp;&nbsp;è¯¢</a>
#                                     </div>
#                                 </div>
#                                 <style>
#                                     .history-list-wrap{
#                                          white-space: nowrap;
#                                          margin:0 auto; overflow: hidden; white-space: nowrap;
#                                     }
#                                     .history-list{
#                                         display: inline;
#                                     }
#                                     .history-list li{
#                                         display: inline;
#                                     }
#                                 </style>
#                                 <div id="search-history">
#                                     <div class="search-history-bd">
#                                         <i id="iconLeftHos" class="history-prev icon icon-caret-left"></i>
#                                         <i id="iconRightHos" class="history-next icon icon-caret-right"></i>
#                                         <div class="history-list-wrap">
#
#                                                     <ul class="history-list" id="history_ul" style="position: relative;">
#
#                                                         </ul>
#
#
#                                         </div>
#                                     </div>
#                                     <div class="search-history-btn">
#                                         <a href="javascript:void(0)">å é¤åå²</a>
#                                     </div>
#                                 </div>
#                             </div>
#                             <!-- å¾è¿ -->
#                             <div class="search-tab-item">
#                                 <div class="search-form">
#                                     <div class="form-item-group">
#                                         <div class="form-item">
#                                             <label for="" class="form-label">åºåå°</label>
#                                             <div class="form-bd">
#                                                 <div class="input-box input-city">
#                                                     <input id="fromStationFan" type="hidden" value="" name="from_station_fan" />
#                                                     <input type="text" class="input" value="" id="fromStationFanText">
#                                                     <i class="icon icon-place" data-click='fromStationFanText'></i>
#                                                 </div>
#                                             </div>
#                                         </div>
#                                         <div class="form-item">
#                                             <label for="" class="form-label">å°è¾¾å°</label>
#                                             <div class="form-bd">
#                                                 <div class="input-box input-city">
#                                                     <input id="toStationFan" type="hidden" value="" name="to_station_fan" />
#                                                     <input type="text" class="input" value="" id="toStationFanText">
#                                                     <i class="icon icon-place" data-click='toStationFanText'></i>
#                                                 </div>
#                                             </div>
#                                         </div>
#                                         <div class="city-change">
#                                             <i class="icon icon-qiehuan" title="åæ¢" id="returnChange"></i>
#                                         </div>
#                                     </div>
#                                     <div class="form-item">
#                                         <label for="" class="form-label">åºåæ¥æ</label>
#                                         <div class="form-bd">
#                                             <div class="input-box input-data">
#                                                 <input type="text" class="input" value="" id="go_date" readonly>
#                                                 <i class="icon icon-date" data-click='go_date'></i>
#                                             </div>
#                                         </div>
#                                     </div>
#                                     <div class="form-item">
#                                         <label for="" class="form-label">è¿ç¨æ¥æ</label>
#                                         <div class="form-bd">
#                                             <div class="input-box input-data">
#                                                 <input type="text" class="input" value="" id="from_date" readonly>
#                                                 <i class="icon icon-date" data-click='from_date'></i>
#                                             </div>
#                                         </div>
#                                     </div>
#                                     <div class="form-item form-item-check">
#                                         <div class="form-bd">
#                                             <ul class="check-list check-list-right">
#                                                 <li id="isStudent">å­¦ç
#                                                     <i></i>
#                                                 </li>
#                                                 <li id="isHigh">é«é/å¨è½¦
#                                                     <i></i>
#                                                 </li>
#                                             </ul>
#                                         </div>
#                                     </div>
#                                     <div class="form-item form-item-btn">
#                                         <a href="javascript:void(0)" class="btn btn-primary form-block" id="search_two">æ¥&nbsp;&nbsp;&nbsp;&nbsp;è¯¢</a>
#                                     </div>
#                                 </div>
#                             </div>
#                             <!-- æ¥ç»­æ¢ä¹ -->
#                             <div class="search-tab-item">
#                                 <div class="search-form">
#                                     <div class="form-item-group">
#                                         <div class="form-item">
#                                             <label for="" class="form-label">
#                                                 <b class="required">*</b>åºåå°</label>
#                                             <div class="form-bd">
#                                                 <div class="input-box input-city">
#                                                     <input id="fromStationSerial" type="hidden" value="" name="from_station_serial" />
#                                                     <input type="text" class="input" value="" id="fromStationSerialText">
#                                                     <i class="icon icon-place" data-click='fromStationSerialText'></i>
#                                                 </div>
#                                             </div>
#                                         </div>
#                                         <div class="form-item">
#                                             <label for="" class="form-label">
#                                                 <b class="required">*</b>å°è¾¾å°</label>
#                                             <div class="form-bd">
#                                                 <div class="input-box input-city">
#                                                     <input id="toStationSerial" type="hidden" value="" name="to_station_serial" />
#                                                     <input type="text" class="input" value="" id="toStationSerialText">
#                                                     <i class="icon icon-place" data-click='toStationSerialText'></i>
#                                                 </div>
#                                             </div>
#                                         </div>
#                                         <div class="city-change">
#                                             <i class="icon icon-qiehuan" title="åæ¢" id="serialChange"></i>
#                                         </div>
#                                     </div>
#                                     <div class="form-item">
#                                         <label for="" class="form-label">
#                                             <b class="required">*</b>ä¹è½¦æ¥æ</label>
#                                         <div class="form-bd">
#                                             <div class="input-box input-data">
#                                                 <input type="text" class="input" value="2018-07-21" id="serial_date"
#                                                     readonly>
#                                                 <i class="icon icon-date" data-click='serial_date'></i>
#                                             </div>
#                                         </div>
#                                     </div>
#                                     <div class="form-item form-item-check">
#                                         <div class="form-bd">
#                                             <ul class="check-list check-list-right">
#                                                 <li id="isStudentLian">å­¦ç
#                                                     <i></i>
#                                                 </li>
#                                             </ul>
#                                         </div>
#                                     </div>
#                                     <div class="form-item form-item-btn">
#                                         <a href="javascript:void(0)" class="btn btn-primary form-block" id="search_three">æ¥&nbsp;&nbsp;&nbsp;&nbsp;è¯¢</a>
#                                     </div>
#                                 </div>
#                             </div>
#                             <!-- éæ¹ç­¾ -->
#                             <div class="search-tab-item">
#                                 <div class="search-form">
#                                     <div class="form-item">
#                                         <span class="form-label">æ¥è¯¢ç±»å</span>
#                                         <div class="form-bd">
#                                             <ul class="radio-list radio-list-ding">
#                                                 <li class="active" id="dingqiaoID">
#                                                     <i></i>è®¢ç¥¨æ¥æ</li>
#                                                 <li>
#                                                     <i></i>ä¹è½¦æ¥æ</li>
#                                             </ul>
#                                         </div>
#                                     </div>
#                                     <div class="form-item">
#                                         <label for="" class="form-label">
#                                             <b class="required">*</b>å¼å§æ¥æ</label>
#                                         <div class="form-bd">
#                                             <div class="input-box input-data">
#                                                 <input type="text" class="input" value="" id="refund_start" readonly>
#                                                 <i class="icon icon-date" data-click='refund_start'></i>
#                                             </div>
#                                         </div>
#                                     </div>
#                                     <div class="form-item">
#                                         <label for="" class="form-label">
#                                             <b class="required">*</b>ç»ææ¥æ</label>
#                                         <div class="form-bd">
#                                             <div class="input-box input-data">
#                                                 <input type="text" class="input" value="" id="refund_end" readonly>
#                                                 <i class="icon icon-date" data-click='refund_end'></i>
#                                             </div>
#                                         </div>
#                                     </div>
#                                     <div class="form-item">
#                                         <label for="" class="form-label">
#                                             <b class="required"></b>å³é®å­</label>
#                                         <div class="form-bd">
#                                             <div class="input-box">
#                                                 <input type="text" class="input search-input" placeholder="è®¢åå·/è½¦æ¬¡/ä¹å®¢å§å"
#                                                     id="refund_code">
#                                             </div>
#                                         </div>
#                                     </div>
#                                     <div class="form-item form-item-btn mt-mlg">
#                                         <a href="javascript:;" class="btn btn-primary form-block" id="refund_button">æ¥&nbsp;&nbsp;&nbsp;&nbsp;è¯¢</a>
#                                     </div>
#                                 </div>
#                             </div>
#                         </div>
#                     </div>
#                 </div>
#                 <!-- å¸¸ç¨æ¥è¯¢ -->
#                 <div class="search-main-item">
#                     <div class="search-main-tab">
#                         <div class="search-tab-hd">
#                             <ul>
#                                 <li class="active">
#                                     <a href="javascript:void(0)">
#                                         <i class="icon icon-shijian"></i>æ­£æç¹</a>
#                                 </li>
#                                 <li>
#                                     <a href="javascript:void(0)">
#                                         <i class="icon icon-jianpiaokou"></i>æ£ç¥¨å£</a>
#                                 </li>
#                                 <li>
#                                     <a href="javascript:void(0)">
#                                         <i class="icon icon-qishou"></i>èµ·å®æ¶é´</a>
#                                 </li>
#                                 <li>
#                                     <a href="javascript:void(0)">
#                                         <i class="icon icon-tianqi"></i>å¤©æ°æ¥è¯¢</a>
#                                 </li>
#                             </ul>
#                         </div>
#                         <div class="search-tab-bd">
#                             <!-- æ­£æç¹ -->
#                             <div class="search-tab-item" style="display: block;">
#                                 <div class="search-form">
#                                     <div class="form-item">
#                                         <span class="form-label">æ¥è¯¢ç±»å</span>
#                                         <div class="form-bd">
#                                             <ul class="radio-list radio-list-station">
#                                                 <li zwd="0" name="zwd_type" class="active" id="destination_station">
#                                                     <i></i>å°è¾¾ç«</li>
#                                                 <li zwd="1" name="zwd_type">
#                                                     <i></i>åºåç«</li>
#                                             </ul>
#                                         </div>
#                                     </div>
#                                     <div class="form-item">
#                                         <label for="" class="form-label">è½¦ç«</label>
#                                         <div class="form-bd">
#                                             <div class="input-box">
# ...
#                                     data-target="_blank" href="javascript:;" class="news-tit">å®åå¶è½¦ç¥¨</a>
#                             </li>
#                             <li>
#                                 <a name="g_href" data-type="2" data-href="gonggao/ticketWindow.html" data-redirect="Y"
#                                     data-target="_blank" href="javascript:;" class="news-tit">å®ç¥¨çªå£è´­ç¥¨</a>
#                             </li>
#                             <li>
#                                 <a name="g_href" data-type="2" data-href="gonggao/onlineBooking.html" data-redirect="Y"
#                                     data-target="_blank" href="javascript:;" class="news-tit">äºèç½è´­ç¥¨ãæ¢ç¥¨</a>
#                             </li>
#                             <li>
#                                 <a name="g_href" data-type="2" data-href="gonggao/onlineEndorse.html" data-redirect="Y"
#                                     data-target="_blank" href="javascript:;" class="news-tit">äºèç½æ¹ç­¾ãåæ´å°ç«</a>
#                             </li>
#                             <li>
#                                 <a name="g_href" data-type="2" data-href="gonggao/onlineRefund.html" data-redirect="Y"
#                                     data-target="_blank" href="javascript:;" class="news-tit">äºèç½éç¥¨</a>
#                             </li>
#                             <li>
#                                 <a name="g_href" data-type="2" data-href="gonggao/luggage.html" data-redirect="Y"
#                                     data-target="_blank" href="javascript:;" class="news-tit">éèº«æºå¸¦å</a>
#                             </li>
#                             <li>
#                                 <a name="g_href" data-type="2" data-href="gonggao/enterAndExit.html" data-redirect="Y"
#                                     data-target="_blank" href="javascript:;" class="news-tit">è¿åºç«</a>
#                             </li>
#                             <li>
#                                 <a name="g_href" data-type="2" data-href="gonggao/ticketLost.html" data-redirect="Y"
#                                     data-target="_blank" href="javascript:;" class="news-tit">ä¸¢å¤±è½¦ç¥¨</a>
#                             </li>
#                             <li>
#                                 <a name="g_href" data-type="2" data-href="gonggao/sgc.html" data-redirect="Y"
#                                     data-target="_blank" href="javascript:;" class="news-tit">ä½¿ç¨å±æ°èº«ä»½è¯ç´æ¥æ£ç¥¨ä¹è½¦</a>
#                             </li>
#                             <li>
#                                 <a name="g_href" data-type="2" data-href="gonggao/gsgcp.html" data-redirect="Y"
#                                     data-target="_blank" href="javascript:;" class="news-tit">å¹¿æ·±æ¸¯è·¨å¢åè½¦</a>
#                             </li>
#                         </ul>
#                         <div class="news-more">
#                             <a name="g_href" data-type="2" data-href="gonggao/help.html" data-redirect="Y" href="javascript:;">æ´å¤></a>
#                         </div>
#                     </div>
#                 </div>
#                 <!-- ä¿¡ç¨ä¿¡æ¯ -->
#                 <div class="tab-item">
#                     <div class="discredit-list-box">
#                         <dl class="discredit-list pull-left">
#                             <dt>
#                                 <i class="icon icon-shixin01"></i>å¤±ä¿¡è¢«æ§è¡äºº(èªç¶äºº)å¬ç¤º</dt>
#                             <div style="height: 128px;overflow: hidden" class="demo">
#                                 <div class="dd_left"></div>
#                             </div>
#                             <dd class="more">
#                                 <a name="g_href" data-type="6" data-href="queryDishonest/init" data-redirect="Y"
#                                     data-target="_blank" href="javascript:;">æ´å¤></a>
#                             </dd>
#                         </dl>
#                         <dl class="discredit-list pull-right">
#                             <dt>
#                                 <i class="icon icon-shixin02"></i>å¤±ä¿¡å·²æ§è¡äºº(èªç¶äºº)å¬å¸</dt>
#                             <div style="height: 128px;overflow: hidden" class="demo1">
#                                 <div class="dd_right"></div>
#                             </div>
#                             <dd class="more">
#                                 <a name="g_href" data-type="6" data-href="queryDishonest/init" data-redirect="Y"
#                                     data-target="_blank" href="javascript:;">æ´å¤></a>
#                             </dd>
#                         </dl>
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </div>
#     <!-- åºé¨ -->
#     <div class="footer">
#         <div class="footer-con wrapper">
#             <div class="foot-links" style="margin-right:20px;">
#                 <h2 class="foot-con-tit">åæé¾æ¥</h2>
#                 <ul class="foot-links-list">
#                     <li>
#                         <a name="g_href" data-href="http://www.china-railway.com.cn/" data-redirect="N" href="javascript:;"
#                             data-target="_blank">
#                             <img src="./images/link01.png" alt="">
#                         </a>
#                     </li>
#                     <li>
#                         <a name="g_href" data-href="http://www.china-ric.com/" data-redirect="N" href="javascript:;"
#                             data-target="_blank">
#                             <img src="./images/link02.png" alt="">
#                         </a>
#                     </li>
#                     <li>
#                         <a name="g_href" data-href="http://www.95306.cn/" data-redirect="N" href="javascript:;"
#                             data-target="_blank">
#                             <img src="./images/link03.png" alt="">
#                         </a>
#                     </li>
#                     <li>
#                         <a name="g_href" data-href="http://www.cre.cn/" data-redirect="N" href="javascript:;"
#                             data-target="_blank">
#                             <img src="./images/link04.png" alt="">
#                         </a>
#                     </li>
#                 </ul>
#             </div>
#             <ul class="foot-code">
# 				<li style="width: 140px;">
# 					<h2 class="foot-con-tit">ä¸­å½éè·¯å®æ¹å¾®ä¿¡</h2>
# 					<div class="code-pic">
# 						<img src="./images/zgtlwb.png">
# 					</div>
# 				</li>
# 				<li  style="width: 140px;">
# 					<h2 class="foot-con-tit">ä¸­å½éè·¯å®æ¹å¾®å</h2>
# 					<div class="code-pic">
# 						<img src="./images/zgtlwx.png">
# 					</div>
# 				</li>
# 				<li  style="width: 110px;">
# 					<h2 class="foot-con-tit">12306 å¬ä¼å·</h2>
# 					<div class="code-pic">
# 						<img src="./images/public.png">
# 					</div>
# 				</li>
# 				<li style="width: 110px;">
# 					<h2 class="foot-con-tit">éè·¯12306</h2>
# 					<div class="code-pic">
# 						<img src="./images/download.png">
# 						<div class="code-tips">å®æ¹APPä¸è½½ï¼ç®åéè·¯æªææå¶ä»ç½ç«æAPPå¼å±ç±»ä¼¼æå¡åå®¹ï¼æ¬è¯·å¹¿å¤§ç¨æ·æ³¨æã</div>
# 					</div>
# 				</li>
# 			</ul>
#         </div>
#         <div class="footer-txt">
#             <p>
#                 <span class="mr">çæææÂ©2008-2018</span>
#                 <span class="mr">ä¸­å½éè·¯ä¿¡æ¯ç§ææéè´£ä»»å¬å¸</span>
#                 <span>ä¸­å½ééç§å­¦ç ç©¶é¢éå¢æéå¬å¸</span>
#             </p>
#             <p>
#                 <span class="mr">äº¬ICPå¤15003716å·-3</span>
#                 <span class="mr">|</span>
#                 <span>äº¬ICPè¯150437å·</span>
#             </p>
#         </div>
#     </div>
#     <!-- è¿åé¡¶é¨ -->
#     <div class="gototop js-top">
#         <a href="javascript:void(0)" class="js-gotop" title="è¿åé¡¶é¨">
#             <i class="icon icon-gotop"></i>
#         </a>
#     </div>
#     <!-- å³ä¾§æ¬æµ®èå -->
#     <div class="fixed-right">
#         <ul class="fixed-right-menu">
#             <li class="menu-item">
#                 <a href="javascript:;" class="menu-hd goGonggao">
#                     <i class="icon icon-notice"></i>
#                     <h4 class="menu-name">ææ°åå¸</h4>
#                 </a>
#             </li>
#             <li class="menu-item">
#                 <a name="g_href" data-type="1" data-href="view/infos/service_number.html" data-redirect="Y" href="javascript:;"
#                     class="menu-hd">
#                     <i class="icon icon-phone"></i>
#                     <h4 class="menu-name">èç³»å®¢æ</h4>
#                 </a>
#             </li>
#             <li class="menu-item">
#                 <a href="javascript:;" class="menu-hd">
#                     <i class="icon icon-code"></i>
#                     <h4 class="menu-name">APPä¸è½½</h4>
#                 </a>
#                 <div class="menu-bd menu-code">
#                     <h4 class="menu-code-name">éè·¯12306</h4>
#                     <div class="menu-code-pic">
#                         <img src="images/download.png">
#                         <div class="code-tips">å®æ¹APPä¸è½½ï¼ç®åéè·¯æªææå¶ä»ç½ç«æAPPå¼å±ç±»ä¼¼æå¡åå®¹ï¼æ¬è¯·å¹¿å¤§ç¨æ·æ³¨æã</div>
#                     </div>
#                 </div>
#             </li>
#             <li class="menu-item">
#                 <a name="g_href" data-type="1" data-href="view/infos/safetyTips.html" data-redirect="Y" class="menu-hd"
#                     href="javascript:;">
#                     <i class="icon icon-reminder"></i>
#                     <h4 class="menu-name">æå®¢åºè¡æ¸©é¦¨æç¤º</h4>
#                 </a>
#             </li>
#         </ul>
#     </div>
#
#     <!-- æ£ç´¢è½¦ç«ä¸ææ¡ -->
#     <div id="search_div" style="z-index: 1000; position: absolute;">
#         <div id="form_cities">
#             <div id="top_cities">
#                 æä½æç¤º
#             </div>
#             <div id="panel_cities"></div>
#             <div id="flip_cities">
#                 ç¿»é¡µæ§å¶åº
#             </div>
#         </div>
#     </div>
#
#     <!-- éæ©è½¦ç«ä¸ææ¡ -->
#     <div id="choice_div" style="z-index: 2000; position: absolute;">
#         <div id="form_cities2">
#             <div id="panel_cities2"></div>
#         </div>
#     </div>
#     <script id="bannerList" type="text/x-handlebars-template">
#         {{#each index_banner_url}}
#         <li style="background: url('{{url}}') center center no-repeat;">
#             {{#if src}} {{#if target}}
#             <a href="{{src}}" target="_blank"></a>
#             {{else}}
#             <a href="{{src}}" target="_self"></a>
#             {{/if}} {{else}}
#             <a></a>
#             {{/if}} {{/each}}
#     </script>
#     <script id="temp1" type="text/x-handlebars-template">
#         {{#each serviceDatas}}
#             <li>
#                 {{#if src}} {{#if target}}
#                 <a href="{{src}}" target="_blank">
#                     <img src="{{img}}">
#                 </a>
#                 {{else}}
#                 <a href="{{src}}" target="_self">
#                     <img src="{{img}}">
#                 </a>
#                 {{/if}} {{else}}
#                 <a>
#                     <img src="{{img}}">
#                 </a>
#                 {{/if}}
#             </li>
#         {{/each}}
#     </script>
#     <script id="temp2" type="text/x-handlebars-template">
#         {{#each service1}}
#         <li>
#             {{#if src}} {{#if target}}
#             <a href="{{src}}" target="_blank">
#                 <div class="service-pic">
#                     <img src="{{img}}">
#                 </div>
#                 <div class="service-info">
#                     <h3 class="service-name">{{title}}</h3>
#                     <p class="service-txt">{{notice}}</p>
#                     <i class="icon icon-more"></i>
#                 </div>
#             </a>
#             {{else}}
#             <a href="{{src}}" target="_self">
#                 <div class="service-pic">
#                     <img src="{{img}}">
#                 </div>
#                 <div class="service-info">
#                     <h3 class="service-name">{{title}}</h3>
#                     <p class="service-txt">{{notice}}</p>
#                     <i class="icon icon-more"></i>
#                 </div>
#             </a>
#             {{/if}} {{else}}
#             <a>
#                 <div class="service-pic">
#                     <img src="{{img}}">
#                 </div>
#                 <div class="service-info">
#                     <h3 class="service-name">{{title}}</h3>
#                     <p class="service-txt">{{notice}}</p>
#                     <i class="icon icon-more"></i>
#                 </div>
#             </a>
#             {{/if}}
#         </li>
#         {{/each}}
#     </script>
#     <script id="travel" type="text/x-handlebars-template">
#         {{#each index_travel_url}}
#         <li>
#             {{#if src}} {{#if target}}
#             <a href="{{src}}" target="_blank">
#                 <div class="travel-pic">
#                     <img src="{{img}}">
#                 </div>
#                 <div class="travel-info">
#                     <h3 class="travel-name">{{title}}</h3>
#                     <div class="txt-price">
#                         <i class="rmb">Â¥</i>{{price}}</div>
#                 </div>
#             </a>
#             {{else}}
#             <a href="{{src}}" target="_self">
#                 <div class="travel-pic">
#                     <img src="{{img}}">
#                 </div>
#                 <div class="travel-info">
#                     <h3 class="travel-name">{{title}}</h3>
#                     <div class="txt-price">
#                         <i class="rmb">Â¥</i>{{price}}</div>
#                 </div>
#             </a>
#             {{/if}} {{else}}
#             <a>
#                 <div class="travel-pic">
#                     <img src="{{img}}">
#                 </div>
#                 <div class="travel-info">
#                     <h3 class="travel-name">{{title}}</h3>
#                     <div class="txt-price">
#                         <i class="rmb">Â¥</i>{{price}}</div>
#                 </div>
#             </a>
#             {{/if}}
#         </li>
#         {{/each}}
#     </script>
#     <script id="news" type="text/x-handlebars-template">
#         {{#each index_news_list}}
#         <li>
#             {{#if src}} {{#if target}}
#             <a target="_blank" style="max-width: 70%;overflow: hidden;text-overflow: ellipsis;white-space: nowrap" href="{{src}}" class="news-tit" title="{{title}}">{{title}}</a>
#             {{else}}
#             <a target="_self" style="max-width: 70%;overflow: hidden;text-overflow: ellipsis;white-space: nowrap" href="{{src}}" class="news-tit" title="{{title}}">{{title}}</a>
#             {{/if}} {{else}}
#             <a style="max-width: 70%;overflow: hidden;text-overflow: ellipsis;white-space: nowrap" class="news-tit" title="{{title}}">{{title}}</a>
#             {{/if}}
#             <span class="news-time">{{date}}</span>
#         </li>
#         {{/each}}
#     </script>
#     <script id="left" type="text/x-handlebars-template">
#         {{#each left}}
#         <dd class="dis-item">
#             <span class="person-name">{{passenger_name}}</span>
#             <span class="person-card">{{passenger_id_no}}</span>
#         </dd>
#         {{/each}}
#     </script>
#     <script id="right" type="text/x-handlebars-template">
#         {{#each right}}
#         <dd class="dis-item">
#             <span class="person-name">{{passenger_name}}</span>
#             <span class="person-card">{{passenger_id_no}}</span>
#         </dd>
#         {{/each}}
#     </script>
#     <script>
#         window.onload = function () {
#             window.pageStart = new Date().getTime();
#         }
#     </script>
#     <script src="https://kyfw.12306.cn/otn/HttpZF/GetJS" type="text/javascript"></script>
#     <script src="script/core/common/qss_v10001.js"></script>
#     <script src="script/core/common/station_name_v10003.js"></script>
#     <script data-main="./script/dist/index/main" src="./script/core/lib/require.js"></script>
# </body>
# </html>

# %% [markdown]
# 这里提示一个错误SSLError，表示证书验证错误。所以，如果请求一个HTTPS站点，但是证书验证错误的页面时，就会报这样的错误，那么如何避免这个错误呢？很简单，把verify参数设置为False即可。

# %%
import requests
 
r = requests.get('https://www.12306.cn',verify=False)
print(r.text)
print(r.url)

# %% [markdown]
# 当然，我们也可以指定一个本地证书用作客户端证书，这可以是单个文件（包含密钥和证书）或一个包含两个文件路径的元组,方法参照官方文档里面的[客户端证书](http://cn.python-requests.org/zh_CN/latest/user/advanced.html#id4)。

# %% [markdown]
# ## 2.5 代理

# %% [markdown]
# 对于某些网站，在测试的时候请求几次，能正常获取内容。但是一旦开始大规模爬取，对于大规模且频繁的请求，网站可能会弹出验证码，或者跳转到登录认证页面，更甚者可能会直接封禁客户端的IP，导致一定时间段内无法访问。
#
# 使用的代理ip可以从[西刺](http://www.xicidaili.com/)获取。
#
# 那么，为了防止这种情况发生，我们需要设置代理来解决这个问题，这就需要用到proxies参数。可以用这样的方式设置：

# %%
import requests
 
# proxies={    
#     'http':'http://118.190.95.43:9001',
#     'https':'http://122.96.93.158:49435'  
# }
 
r = requests.get('http://httpbin.org/get')
print(r.text)
# Out:
# {
#   "args": {},
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Connection": "close",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.19.1"
#   },
#   "origin": "183.15.178.105",
#   "url": "http://httpbin.org/get"
# }

# %%
import requests

proxies = {
    'http':'http://171.41.82.86:9999'
}
r=requests.get('http://httpbin.org/get',proxies=proxies)
print(r.text)
# Out:
# {
#   "args": {},
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Cache-Control": "max-age=259200",
#     "Connection": "close",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.19.1"
#   },
#   "origin": "171.41.82.86",
#   "url": "http://httpbin.org/get"
# }

# %% [markdown]
# 其他的设置方法见[官方文档](http://cn.python-requests.org/zh_CN/latest/user/advanced.html#proxies)。

# %% [markdown]
# ## 2.6 自定义身份验证

# %% [markdown]
# Requests 允许你使用自己指定的身份验证机制。详情见[官方文档](http://cn.python-requests.org/zh_CN/latest/user/advanced.html#custom-auth)。
#
# 任何传递给请求方法的 auth 参数的可调用对象，在请求发出之前都有机会修改请求

# %%
import requests
from requests.auth import HTTPBasicAuth
 
r = requests.get('https://mail.163.com/', auth=HTTPBasicAuth('17727478517@163.com', 'Youlzhang315088'))
print(r.status_code)
print(r.url)
# Out:
# 200
# https://mail.163.com/

# %% [markdown]
# 当然，如果参数都传一个HTTPBasicAuth类，就显得有点烦琐了，所以requests提供了一个更简单的写法，可以直接传一个元组，它会默认使用HTTPBasicAuth这个类来认证。
#
# 所以上面的代码可以直接简写如下：

# %%
import requests
from requests.auth import HTTPBasicAuth
 
r = requests.get('http://pizzabin.org/admin', auth=('username', 'password'))
print(r.status_code)

# %% [markdown]
# ## 2.7 Prepared Request

# %% [markdown]
# 前面介绍urllib时，我们可以将请求表示为数据结构，其中各个参数都可以通过一个Request对象来表示。这在requests里同样可以做到，这个数据结构就叫[Prepared Request](http://cn.python-requests.org/zh_CN/latest/user/advanced.html#prepared-request)。我们用实例看一下：

# %%
from requests import Request, Session
 
url = 'http://httpbin.org/post'
data = {
    'name': 'germey'
}
headers = {
    'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/53.0.2785.116 Safari/537.36'
}
s = Session()
req = Request('POST', url, data=data, headers=headers)
#print(req)
prepped = s.prepare_request(req)
r = s.send(prepped)
print(r.text)

# %% [markdown]
# 有了Request这个对象，就可以将请求当作独立的对象来看待，这样在进行队列调度时会非常方便。

# %% [markdown]
# ## 2.8 超时

# %% [markdown]
# 在本机网络状况不好或者服务器网络响应太慢甚至无响应时，我们可能会等待特别久的时间才可能收到响应，甚至到最后收不到响应而报错。为了防止服务器不能及时响应，应该设置一个超时时间，即超过了这个时间还没有得到响应，那就报错。这需要用到timeout参数。这个时间的计算是发出请求到服务器返回响应的时间。示例如下：

# %%
import requests
 
r = requests.get("https://www.google.com",timeout=0.1)
print(r.status_code)
# Out:
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# D:\ProgramData\Anaconda3\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     170             conn = connection.create_connection(
# --> 171                 (self._dns_host, self.port), self.timeout, **extra_kw)
#     172
#
# D:\ProgramData\Anaconda3\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      78     if err is not None:
# ---> 79         raise err
#      80
#
# D:\ProgramData\Anaconda3\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      68                 sock.bind(source_address)
# ---> 69             sock.connect(sa)
#      70             return sock
#
# timeout: timed out
#
# During handling of the above exception, another exception occurred:
#
# ConnectTimeoutError                       Traceback (most recent call last)
# D:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#
# D:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     342         try:
# --> 343             self._validate_conn(conn)
#     344         except (SocketTimeout, BaseSSLError) as e:
#
# D:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _validate_conn(self, conn)
#     848         if not getattr(conn, 'sock', None):  # AppEngine might not have  `.sock`
# --> 849             conn.connect()
#     850
#
# D:\ProgramData\Anaconda3\lib\site-packages\urllib3\connection.py in connect(self)
#     313         # Add certificate verification
# --> 314         conn = self._new_conn()
#     315
#
# D:\ProgramData\Anaconda3\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     175                 self, "Connection to %s timed out. (connect timeout=%s)" %
# --> 176                 (self.host, self.timeout))
#     177
#
# ConnectTimeoutError: (<urllib3.connection.VerifiedHTTPSConnection object at 0x0000000005315EF0>, 'Connection to www.google.com timed out. (connect timeout=0.1)')
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# D:\ProgramData\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     444                     retries=self.max_retries,
# --> 445                     timeout=timeout
#     446                 )
#
# D:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     637             retries = retries.increment(method, url, error=e, _pool=self,
# --> 638                                         _stacktrace=sys.exc_info()[2])
#     639             retries.sleep()
#
# D:\ProgramData\Anaconda3\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     397         if new_retry.is_exhausted():
# --> 398             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     399
#
# MaxRetryError: HTTPSConnectionPool(host='www.google.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x0000000005315EF0>, 'Connection to www.google.com timed out. (connect timeout=0.1)'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectTimeout                            Traceback (most recent call last)
# <ipython-input-76-7de68e1dd6a0> in <module>()
#       1 import requests
#       2
# ----> 3 r = requests.get("https://www.google.com",timeout=0.1)
#       4 print(r.status_code)
#
# D:\ProgramData\Anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      70
#      71     kwargs.setdefault('allow_redirects', True)
# ---> 72     return request('get', url, params=params, **kwargs)
#      73
#      74
#
# D:\ProgramData\Anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# D:\ProgramData\Anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     510         }
#     511         send_kwargs.update(settings)
# --> 512         resp = self.send(prep, **send_kwargs)
#     513
#     514         return resp
#
# D:\ProgramData\Anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     620
#     621         # Send the request
# --> 622         r = adapter.send(request, **kwargs)
#     623
#     624         # Total elapsed time of the request (approximately)
#
# D:\ProgramData\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     499                 # TODO: Remove this in 3.0.0: see #2811
#     500                 if not isinstance(e.reason, NewConnectionError):
# --> 501                     raise ConnectTimeout(e, request=request)
#     502
#     503             if isinstance(e.reason, ResponseError):
#
# ConnectTimeout: HTTPSConnectionPool(host='www.google.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x0000000005315EF0>, 'Connection to www.google.com timed out. (connect timeout=0.1)'))

# %% [markdown]
# 这一 timeout 值将会用作 connect 和 read 二者的 timeout。如果要分别制定，就传入一个元组：

# %%
import requests
 
r = requests.get("https://www.taobao.com", timeout =(1,1))
print(r.status_code)
# Out:
# 200

# %% [markdown]
# 如果远端服务器很慢，你可以让 Request 永远等待，传入一个 None 作为 timeout 值，然后就冲咖啡去吧。

# %%
import requests
 
r = requests.get('https://www.google.com', timeout=None)
print(r.status_code)
# Out:
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# d:\program files\python3.6\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     140             conn = connection.create_connection(
# --> 141                 (self.host, self.port), self.timeout, **extra_kw)
#     142
#
# d:\program files\python3.6\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      82     if err is not None:
# ---> 83         raise err
#      84
#
# d:\program files\python3.6\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      72                 sock.bind(source_address)
# ---> 73             sock.connect(sa)
#      74             return sock
#
# timeout: timed out
#
# During handling of the above exception, another exception occurred:
#
# ConnectTimeoutError                       Traceback (most recent call last)
# d:\program files\python3.6\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     600                                                   body=body, headers=headers,
# --> 601                                                   chunked=chunked)
#     602
#
# d:\program files\python3.6\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     345         try:
# --> 346             self._validate_conn(conn)
#     347         except (SocketTimeout, BaseSSLError) as e:
#
# d:\program files\python3.6\lib\site-packages\urllib3\connectionpool.py in _validate_conn(self, conn)
#     849         if not getattr(conn, 'sock', None):  # AppEngine might not have  `.sock`
# --> 850             conn.connect()
#     851
#
# d:\program files\python3.6\lib\site-packages\urllib3\connection.py in connect(self)
#     283         # Add certificate verification
# --> 284         conn = self._new_conn()
#     285
#
# d:\program files\python3.6\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     145                 self, "Connection to %s timed out. (connect timeout=%s)" %
# --> 146                 (self.host, self.timeout))
#     147
#
# ConnectTimeoutError: (<urllib3.connection.VerifiedHTTPSConnection object at 0x000000000577A208>, 'Connection to www.google.com timed out. (connect timeout=1)')
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# d:\program files\python3.6\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     439                     retries=self.max_retries,
# --> 440                     timeout=timeout
#     441                 )
#
# d:\program files\python3.6\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     638             retries = retries.increment(method, url, error=e, _pool=self,
# --> 639                                         _stacktrace=sys.exc_info()[2])
#     640             retries.sleep()
#
# d:\program files\python3.6\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     387         if new_retry.is_exhausted():
# --> 388             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     389
#
# MaxRetryError: HTTPSConnectionPool(host='www.google.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x000000000577A208>, 'Connection to www.google.com timed out. (connect timeout=1)'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectTimeout                            Traceback (most recent call last)
# <ipython-input-39-7eacfb74d6bd> in <module>()
#       1 import requests
#       2
# ----> 3 r = requests.get('https://www.google.com', timeout=1)
#       4 print(r.status_code)
#
# d:\program files\python3.6\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      70
#      71     kwargs.setdefault('allow_redirects', True)
# ---> 72     return request('get', url, params=params, **kwargs)
#      73
#      74
#
# d:\program files\python3.6\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# d:\program files\python3.6\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     506         }
#     507         send_kwargs.update(settings)
# --> 508         resp = self.send(prep, **send_kwargs)
#     509
#     510         return resp
#
# d:\program files\python3.6\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     616
#     617         # Send the request
# --> 618         r = adapter.send(request, **kwargs)
#     619
#     620         # Total elapsed time of the request (approximately)
#
# d:\program files\python3.6\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     494                 # TODO: Remove this in 3.0.0: see #2811
#     495                 if not isinstance(e.reason, NewConnectionError):
# --> 496                     raise ConnectTimeout(e, request=request)
#     497
#     498             if isinstance(e.reason, ResponseError):
#
# ConnectTimeout: HTTPSConnectionPool(host='www.google.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x000000000577A208>, 'Connection to www.google.com timed out. (connect timeout=1)'))

# %% [markdown]
# # 3. 异常

# %% [markdown]
# 关于异常的[官方文档](http://cn.python-requests.org/zh_CN/latest/api.html#id3)

# %%
import requests
from requests.exceptions import Timeout,HTTPError,RequestException,ConnectionError,ReadTimeout

try:
    r = requests.get('http://www.youliang.com')
    print(r.text)
except ReadTimeout:
    print('TimeOut')
except HTTPError:
    print('Http Error')
except ConnectionError:
    print('Connection Error')
except RequestException:
    print('Error')
# Out:
# Error

# %%
help(UserAgent)
# Out:
# Help on class FakeUserAgent in module fake_useragent.fake:
#
# class FakeUserAgent(builtins.object)
#  |  FakeUserAgent(cache=True, use_cache_server=True, path='C:\\Users\\ADMINI~1\\AppData\\Local\\Temp\\fake_useragent_0.1.11.json', fallback=None, verify_ssl=True, safe_attrs=())
#  |
#  |  Methods defined here:
#  |
#  |  __getattr__(self, attr)
#  |
#  |  __getitem__(self, attr)
#  |
#  |  __init__(self, cache=True, use_cache_server=True, path='C:\\Users\\ADMINI~1\\AppData\\Local\\Temp\\fake_useragent_0.1.11.json', fallback=None, verify_ssl=True, safe_attrs=())
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  load(self)
#  |
#  |  update(self, cache=None)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)

# %%
from fake_useragent import UserAgent
ua = UserAgent()
ua.random
# Out:
# 'Mozilla/5.0 (Windows NT 6.2) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/28.0.1467.0 Safari/537.36'
